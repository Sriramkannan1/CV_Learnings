# %% [markdown]
# <a href="https://colab.research.google.com/github/Sriramkannan1/DL_Learnings/blob/main/Bidirectional_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.datasets
from sklearn.model_selection import train_test_split

# %%
from tensorflow import keras as kr
from tensorflow.keras import layers,models,datasets

# %%
d=kr.datasets.mnist
(x_train,y_train),(x_test,y_test)=d.load_data()
x_train,x_test=x_train/255.0,x_test/255.0

# %%
from tensorflow.keras import Input, models
from tensorflow.keras.layers import LSTM, Dense, Bidirectional

# %%
input_shape = (28, 28)
inputs = Input(shape=input_shape)
rnn = Bidirectional(LSTM(128))(inputs)

# %%
outputs = Dense(10, activation='softmax')(rnn)

model = models.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()

# %%
model.compile(optimizer="adam",
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model=model.fit(x_train,y_train,validation_split=0.1,epochs=10)

# %%
plt.plot(model.history["accuracy"])
plt.plot(model.history['val_accuracy'])
plt.title("model accuracy")
plt.xlabel("epoch")
plt.ylabel("Accuracy")
plt.legend(['training data','validation data'],loc='lower right')

# %%
plt.plot(model.history['loss'])
plt.plot(model.history['val_loss'])
plt.title("model loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(['trainig data','validation data'],loc='lower right')
